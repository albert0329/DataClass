# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from config import yelp_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

cities_chosen = pd.DataFrame(cities, columns=['city_name'])
#cities_chosen = cities_chosen.replace[' ', '%20']
cities_chosen.count()
# Out:
# city_name    621
# dtype: int64

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities_chosen['Latitude'] =''
cities_chosen['Longitude'] = ''
cities_chosen['Temperature'] = ''
cities_chosen['Humidity'] = ''
cities_chosen['Cloudiness'] = ''
cities_chosen['Wind_Speed'] = ''

count_row = 0

print("Beginning Data Retrieval")
print("-----------------------------")

for index, row in cities_chosen.iterrows():
    time.sleep(1)
    
    url = "https://api.openweathermap.org/data/2.5/weather?"
    units = "metric"
    #params = {"q": row["city_name"], "APPID": yelp_key}
    query_url = url + "q=" + str(row["city_name"]) + "&APPID=" + yelp_key + "&units=" + units
    
    
    weather_response = requests.get(query_url)
    weather_data = weather_response.json()
    
    count_row += 1
    
    if weather_response.status_code != requests.codes.ok:
        print(f'Processing Record {str(count_row)} | {row["city_name"]} {weather_response.text}')
        
    else:
        print(f'Processing Record {str(count_row)} | {row["city_name"]}')
        
    try:
        longitude = weather_data['coord']['lon']
        latitude = weather_data['coord']['lat']
        temperature = weather_data["main"]["temp"]
        humidity = weather_data["main"]["humidity"]
        cloudiness = weather_data["clouds"]["all"]
        wind_speed = weather_data["wind"]["speed"]
        
        cities_chosen.at[index,'Longitude'] = longitude
        cities_chosen.at[index,'Latitude'] = latitude
        cities_chosen.at[index,'Temperature'] = temperature
        cities_chosen.at[index, 'Humidity'] = humidity
        cities_chosen.at[index, 'Cloudiness'] = cloudiness
        cities_chosen.at[index, 'Wind_Speed'] = wind_speed
    except:
        print("No weather data")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | dikson
# Processing Record 2 | torbay
# Processing Record 3 | yellowknife
# Processing Record 4 | tarakan
# Processing Record 5 | atuona
# Processing Record 6 | yakovlevka
# Processing Record 7 | kapaa
# Processing Record 8 | belushya guba {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 9 | buin
# Processing Record 10 | marrakesh
# Processing Record 11 | avarua
# Processing Record 12 | ushuaia
# Processing Record 13 | taolanaro {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 14 | hermanus
# Processing Record 15 | rikitea
# Processing Record 16 | candolim
# Processing Record 17 | hilo
# Processing Record 18 | hithadhoo
# Processing Record 19 | sisimiut
# Processing Record 20 | arlit
# Processing Record 21 | ugoofaaru
# Processing Record 22 | barentsburg {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 23 | port blair
# Processing Record 24 | kaberamaido
# Processing Record 25 | mount isa
# Processing Record 26 | thompson
# Processing Record 27 | flin flon
# Processing Record 28 | auki
# Processing Record 29 | chapais
# Processing Record 30 | minab
# Processing Record 31 | sitka
# Processing Record 32 | nanortalik
# Processing Record 33 | pangnirtung
# Processing Record 34 | georgetown
# Processing Record 35 | aksha
# Processing Record 36 | nyrob
# Processing Record 37 | birjand
# Processing Record 38 | esfahan
# Processing Record 39 | albany
# Processing Record 40 | busselton
# Processing Record 41 | tiksi
# Processing Record 42 | ozgon {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 43 | marzuq
# Processing Record 44 | vaini
# Processing Record 45 | jamestown
# Processing Record 46 | margate
# Processing Record 47 | moose factory
# Processing Record 48 | port lincoln
# Processing Record 49 | cape town
# Processing Record 50 | kaz
# Processing Record 51 | upernavik
# Processing Record 52 | souillac
# Processing Record 53 | hobart
# Processing Record 54 | the valley
# Processing Record 55 | kirra
# Processing Record 56 | new norfolk
# Processing Record 57 | kaitangata
# Processing Record 58 | platonovka {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 59 | qaanaaq
# Processing Record 60 | artur nogueira
# Processing Record 61 | provideniya
# Processing Record 62 | liverpool
# Processing Record 63 | faya
# Processing Record 64 | cap-chat
# Processing Record 65 | gigmoto
# Processing Record 66 | tallahassee
# Processing Record 67 | lazarev
# Processing Record 68 | lolua {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 69 | okhotsk
# Processing Record 70 | punta arenas
# Processing Record 71 | marienburg
# Processing Record 72 | tsihombe {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 73 | port alfred
# Processing Record 74 | puerto ayora
# Processing Record 75 | mlonggo
# Processing Record 76 | bethel
# Processing Record 77 | nianzishan
# Processing Record 78 | capinopolis
# Processing Record 79 | newry
# Processing Record 80 | mill valley
# Processing Record 81 | hay river
# Processing Record 82 | kodiak
# Processing Record 83 | yar-sale
# Processing Record 84 | mujiayingzi
# Processing Record 85 | port hedland
# Processing Record 86 | mar del plata
# Processing Record 87 | carnarvon
# Processing Record 88 | fortuna
# Processing Record 89 | khatanga
# Processing Record 90 | castro
# Processing Record 91 | thinadhoo
# Processing Record 92 | port hardy
# Processing Record 93 | pisco
# Processing Record 94 | billings
# Processing Record 95 | alofi
# Processing Record 96 | aden
# Processing Record 97 | huazolotitlan {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 98 | vitim
# Processing Record 99 | victoria
# Processing Record 100 | saskylakh
# Processing Record 101 | chokurdakh
# Processing Record 102 | lamu
# Processing Record 103 | marawi
# Processing Record 104 | geraldton
# Processing Record 105 | japura
# Processing Record 106 | ponta do sol
# Processing Record 107 | viseu
# Processing Record 108 | nemuro
# Processing Record 109 | chuy
# Processing Record 110 | pacific grove
# Processing Record 111 | balkanabat
# Processing Record 112 | namatanai
# Processing Record 113 | changzhou
# Processing Record 114 | naryan-mar
# Processing Record 115 | mae hong son
# Processing Record 116 | dwarka
# Processing Record 117 | xiangxiang
# Processing Record 118 | ostrovnoy
# Processing Record 119 | ancud
# Processing Record 120 | barrow
# Processing Record 121 | tuktoyaktuk
# Processing Record 122 | ambon
# Processing Record 123 | narsaq
# Processing Record 124 | olafsvik {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 125 | amderma {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 126 | batagay-alyta
# Processing Record 127 | avera
# Processing Record 128 | honiara
# Processing Record 129 | saint anthony
# Processing Record 130 | bathsheba
# Processing Record 131 | waipawa
# Processing Record 132 | bera
# Processing Record 133 | soanierana ivongo
# Processing Record 134 | dhidhdhoo
# Processing Record 135 | bredasdorp
# Processing Record 136 | hastings
# Processing Record 137 | vaitupu {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 138 | pangkalanbuun
# Processing Record 139 | stephenville
# Processing Record 140 | karavayevo
# Processing Record 141 | illoqqortoormiut {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 142 | camacupa
# Processing Record 143 | grand river south east {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 144 | tuatapere
# Processing Record 145 | butaritari
# Processing Record 146 | bluff
# Processing Record 147 | kirakira
# Processing Record 148 | iqaluit
# Processing Record 149 | louisbourg {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 150 | manzhouli
# Processing Record 151 | itarema
# Processing Record 152 | guerrero negro
# Processing Record 153 | oistins
# Processing Record 154 | inhambane
# Processing Record 155 | sambava
# Processing Record 156 | ramos arizpe
# Processing Record 157 | lebu
# Processing Record 158 | yulara
# Processing Record 159 | bambous virieux
# Processing Record 160 | buckeye
# Processing Record 161 | sebinkarahisar
# Processing Record 162 | leland
# Processing Record 163 | zeya
# Processing Record 164 | vila velha
# Processing Record 165 | tumannyy {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 166 | constitucion
# Processing Record 167 | longyearbyen
# Processing Record 168 | kavieng
# Processing Record 169 | qax
# Processing Record 170 | goulburn
# Processing Record 171 | cherskiy
# Processing Record 172 | harrison
# Processing Record 173 | kenai
# Processing Record 174 | tautira
# Processing Record 175 | kawalu
# Processing Record 176 | nouadhibou
# Processing Record 177 | pevek
# Processing Record 178 | hede
# Processing Record 179 | college
# Processing Record 180 | harlingen
# Processing Record 181 | ngunguru
# Processing Record 182 | bonavista
# Processing Record 183 | dalianwan
# Processing Record 184 | dovers
# Processing Record 185 | puri
# Processing Record 186 | grand-lahou
# Processing Record 187 | ilek
# Processing Record 188 | severo-kurilsk
# Processing Record 189 | mataura
# Processing Record 190 | qaqortoq
# Processing Record 191 | saint-augustin
# Processing Record 192 | saleaula {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 193 | akureyri
# Processing Record 194 | okha
# Processing Record 195 | nikolskoye
# Processing Record 196 | batagay
# Processing Record 197 | maine-soroa
# Processing Record 198 | marsh harbour
# Processing Record 199 | katsuura
# Processing Record 200 | roslavl
# Processing Record 201 | kloulklubed
# Processing Record 202 | meulaboh
# Processing Record 203 | ribeira grande
# Processing Record 204 | east london
# Processing Record 205 | ormara
# Processing Record 206 | arraial do cabo
# Processing Record 207 | acari
# Processing Record 208 | borodino
# Processing Record 209 | portland
# Processing Record 210 | sampit
# Processing Record 211 | vrangel
# Processing Record 212 | salalah
# Processing Record 213 | lompoc
# Processing Record 214 | yanam
# Processing Record 215 | cervo
# Processing Record 216 | samusu {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 217 | vanimo
# Processing Record 218 | zlatoustovsk {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 219 | deputatskiy
# Processing Record 220 | atambua
# Processing Record 221 | sao miguel do araguaia
# Processing Record 222 | male
# Processing Record 223 | norman wells
# Processing Record 224 | samarinda
# Processing Record 225 | rokytne
# Processing Record 226 | atar
# Processing Record 227 | cockburn town
# Processing Record 228 | ust-tsilma
# Processing Record 229 | saint-joseph
# Processing Record 230 | macon
# Processing Record 231 | bengkulu {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 232 | alekseyevsk
# Processing Record 233 | rabo de peixe
# Processing Record 234 | vila franca do campo
# Processing Record 235 | attawapiskat {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 236 | san pedro
# Processing Record 237 | babu
# Processing Record 238 | vao
# Processing Record 239 | rungata {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 240 | sentyabrskiy {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 241 | qiqihar
# Processing Record 242 | umzimvubu {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 243 | srivardhan
# Processing Record 244 | port elizabeth
# Processing Record 245 | richards bay
# Processing Record 246 | barddhaman
# Processing Record 247 | brae
# Processing Record 248 | banepa
# Processing Record 249 | cognac
# Processing Record 250 | phuket
# Processing Record 251 | rio gallegos
# Processing Record 252 | faanui
# Processing Record 253 | bellingham
# Processing Record 254 | klaksvik
# Processing Record 255 | kamenka
# Processing Record 256 | aquiraz
# Processing Record 257 | cidreira
# Processing Record 258 | muisne
# Processing Record 259 | jiuquan
# Processing Record 260 | nova olimpia
# Processing Record 261 | onguday
# Processing Record 262 | boende
# Processing Record 263 | nizhneyansk {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 264 | samalaeulu {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 265 | alberton
# Processing Record 266 | kahului
# Processing Record 267 | turukhansk
# Processing Record 268 | ijaki {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 269 | clyde river
# Processing Record 270 | ustye
# Processing Record 271 | saint-philippe
# Processing Record 272 | sinjah {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 273 | finnsnes
# Processing Record 274 | kapoeta {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 275 | lusambo
# Processing Record 276 | sur
# Processing Record 277 | saint george
# Processing Record 278 | berbera {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 279 | panaba
# Processing Record 280 | lagoa
# Processing Record 281 | ouallam
# Processing Record 282 | laguna
# Processing Record 283 | talcahuano
# Processing Record 284 | luanda
# Processing Record 285 | coquimbo
# Processing Record 286 | dno
# Processing Record 287 | hasaki
# Processing Record 288 | krasnaya gora
# Processing Record 289 | khandbari
# Processing Record 290 | kappeln
# Processing Record 291 | champerico
# Processing Record 292 | fengrun
# Processing Record 293 | santiago del estero
# Processing Record 294 | grand gaube
# Processing Record 295 | victor rosales {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 296 | trairi
# Processing Record 297 | julio de castilhos
# Processing Record 298 | temerloh
# Processing Record 299 | haselunne
# Processing Record 300 | izazi
# Processing Record 301 | mareeba
# Processing Record 302 | sao filipe
# Processing Record 303 | tanggu {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 304 | baruun-urt
# Processing Record 305 | muros
# Processing Record 306 | half moon bay
# Processing Record 307 | cabo san lucas
# Processing Record 308 | kirn
# Processing Record 309 | nurobod
# Processing Record 310 | alyangula
# Processing Record 311 | dubbo
# Processing Record 312 | inuvik
# Processing Record 313 | sorong
# Processing Record 314 | phan rang {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 315 | catende
# Processing Record 316 | korla {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 317 | fantino
# Processing Record 318 | manggar
# Processing Record 319 | samarai
# Processing Record 320 | yeppoon
# Processing Record 321 | santiago
# Processing Record 322 | nuuk
# Processing Record 323 | wanning
# Processing Record 324 | south yuba city
# Processing Record 325 | kavaratti
# Processing Record 326 | troitsko-pechorsk
# Processing Record 327 | bose
# Processing Record 328 | romny
# Processing Record 329 | changping
# Processing Record 330 | leirvik
# Processing Record 331 | lubon
# Processing Record 332 | nautla
# Processing Record 333 | rawson
# Processing Record 334 | jucuaran
# Processing Record 335 | miri
# Processing Record 336 | saint-francois
# Processing Record 337 | harper
# Processing Record 338 | kruisfontein
# Processing Record 339 | forbes
# Processing Record 340 | mnogovershinnyy
# Processing Record 341 | coahuayana
# Processing Record 342 | natchitoches
# Processing Record 343 | walvis bay
# Processing Record 344 | tasiilaq
# Processing Record 345 | gazimurskiy zavod
# Processing Record 346 | san patricio
# Processing Record 347 | de aar
# Processing Record 348 | duz {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 349 | ponta delgada
# Processing Record 350 | preston
# Processing Record 351 | chake chake
# Processing Record 352 | akcakoca
# Processing Record 353 | vestmanna
# Processing Record 354 | ugep
# Processing Record 355 | lillesand
# Processing Record 356 | korkino
# Processing Record 357 | mecca
# Processing Record 358 | magadan
# Processing Record 359 | poum
# Processing Record 360 | arandis
# Processing Record 361 | quepos
# Processing Record 362 | marcona {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 363 | leningradskiy
# Processing Record 364 | joshimath
# Processing Record 365 | veraval
# Processing Record 366 | madaoua
# Processing Record 367 | santa fe
# Processing Record 368 | sarh
# Processing Record 369 | gao
# Processing Record 370 | upata
# Processing Record 371 | banda aceh
# Processing Record 372 | altos
# Processing Record 373 | san rafael
# Processing Record 374 | lorengau
# Processing Record 375 | gulshat {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 376 | luderitz
# Processing Record 377 | singaraja
# Processing Record 378 | espirito santo do pinhal
# Processing Record 379 | zhigansk
# Processing Record 380 | bandarbeyla
# Processing Record 381 | palabuhanratu {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 382 | caravelas
# Processing Record 383 | thoen
# Processing Record 384 | synya
# Processing Record 385 | calama
# Processing Record 386 | vuktyl
# Processing Record 387 | homnabad
# Processing Record 388 | gizo
# Processing Record 389 | tonshayevo
# Processing Record 390 | kambove
# Processing Record 391 | acapulco
# Processing Record 392 | kencong
# Processing Record 393 | amahai
# Processing Record 394 | ondo
# Processing Record 395 | naze
# Processing Record 396 | solnechnyy
# Processing Record 397 | mahebourg
# Processing Record 398 | tomatlan
# Processing Record 399 | goderich
# Processing Record 400 | dawei
# Processing Record 401 | piracanjuba
# Processing Record 402 | abonnema
# Processing Record 403 | jinchang
# Processing Record 404 | mys shmidta {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 405 | luwuk
# Processing Record 406 | roald
# Processing Record 407 | tukrah {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 408 | barbar {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 409 | egvekinot
# Processing Record 410 | moses lake
# Processing Record 411 | bandundu
# Processing Record 412 | yaan
# Processing Record 413 | nova granada
# Processing Record 414 | sao felix do xingu
# Processing Record 415 | pessac
# Processing Record 416 | bayburt
# Processing Record 417 | ko samui
# Processing Record 418 | hokitika
# Processing Record 419 | yarada
# Processing Record 420 | lavrentiya
# Processing Record 421 | george
# Processing Record 422 | zhaozhou
# Processing Record 423 | grindavik
# Processing Record 424 | salinas
# Processing Record 425 | khonuu {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 426 | ulladulla
# Processing Record 427 | zaozerne
# Processing Record 428 | ewo
# Processing Record 429 | puruaran
# Processing Record 430 | keningau
# Processing Record 431 | along
# Processing Record 432 | diego de almagro
# Processing Record 433 | isangel
# Processing Record 434 | nguiu {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 435 | luganville
# Processing Record 436 | aasiaat
# Processing Record 437 | mezocsat
# Processing Record 438 | kadhan
# Processing Record 439 | mae sai
# Processing Record 440 | celestun
# Processing Record 441 | peekskill
# Processing Record 442 | north bend
# Processing Record 443 | yanan {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 444 | hofn
# Processing Record 445 | kysyl-syr
# Processing Record 446 | belawan
# Processing Record 447 | bonthe
# Processing Record 448 | mendi
# Processing Record 449 | namtsy
# Processing Record 450 | kolobrzeg
# Processing Record 451 | kuching
# Processing Record 452 | karratha
# Processing Record 453 | kandrian
# Processing Record 454 | codrington
# Processing Record 455 | palora
# Processing Record 456 | omsukchan
# Processing Record 457 | nurlat
# Processing Record 458 | peiting
# Processing Record 459 | matamoros
# Processing Record 460 | port-gentil
# Processing Record 461 | la paz
# Processing Record 462 | mwinilunga
# Processing Record 463 | chumikan
# Processing Record 464 | istisu
# Processing Record 465 | asfi {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 466 | lhuntshi {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 467 | talnakh
# Processing Record 468 | aviles
# Processing Record 469 | juba
# Processing Record 470 | fallon
# Processing Record 471 | burica {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 472 | araceli
# Processing Record 473 | merauke
# Processing Record 474 | port-cartier
# Processing Record 475 | groningen
# Processing Record 476 | boguchany
# Processing Record 477 | zyryanovsk
# Processing Record 478 | nome
# Processing Record 479 | praya
# Processing Record 480 | labuhan
# Processing Record 481 | vysoke myto
# Processing Record 482 | hammerfest
# Processing Record 483 | nantucket
# Processing Record 484 | kismayo {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 485 | taksimo
# Processing Record 486 | teahupoo
# Processing Record 487 | santa cruz de tenerife
# Processing Record 488 | cagayan de tawi-tawi {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 489 | black river
# Processing Record 490 | svetlyy {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 491 | wajima
# Processing Record 492 | soma
# Processing Record 493 | comodoro rivadavia
# Processing Record 494 | aykhal
# Processing Record 495 | monastyrshchina
# Processing Record 496 | bac lieu {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 497 | petropavlovsk-kamchatskiy
# Processing Record 498 | olonets
# Processing Record 499 | adrar
# Processing Record 500 | puro
# Processing Record 501 | nurota
# Processing Record 502 | mabaruma
# Processing Record 503 | komsomolskiy
# Processing Record 504 | makat
# Processing Record 505 | russell
# Processing Record 506 | tabou
# Processing Record 507 | henties bay
# Processing Record 508 | ahipara
# Processing Record 509 | dunedin
# Processing Record 510 | broken hill
# Processing Record 511 | airai
# Processing Record 512 | amapa
# Processing Record 513 | koyilandi {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 514 | varangaon
# Processing Record 515 | baykit
# Processing Record 516 | emporia
# Processing Record 517 | kudahuvadhoo
# Processing Record 518 | villers-les-nancy
# Processing Record 519 | zitiste
# Processing Record 520 | dolbeau {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 521 | porto novo
# Processing Record 522 | abha
# Processing Record 523 | alta floresta
# Processing Record 524 | boa vista
# Processing Record 525 | krasnoyarsk-45 {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 526 | mathathane
# Processing Record 527 | suratgarh
# Processing Record 528 | dingle
# Processing Record 529 | sunrise manor
# Processing Record 530 | muroran
# Processing Record 531 | foam lake
# Processing Record 532 | tilichiki
# Processing Record 533 | saldanha
# Processing Record 534 | vardo
# Processing Record 535 | murgab
# Processing Record 536 | sion
# Processing Record 537 | ituni {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 538 | loding
# Processing Record 539 | mailsi
# Processing Record 540 | sanok
# Processing Record 541 | padang
# Processing Record 542 | awjilah
# Processing Record 543 | puerto leguizamo
# Processing Record 544 | weligama
# Processing Record 545 | alamosa
# Processing Record 546 | varberg
# Processing Record 547 | pedernales
# Processing Record 548 | pasighat
# Processing Record 549 | ibra
# Processing Record 550 | ampere
# Processing Record 551 | sola
# Processing Record 552 | aflu {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 553 | xinqing
# Processing Record 554 | srednekolymsk
# Processing Record 555 | turkistan {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 556 | manjacaze
# Processing Record 557 | paranaiba
# Processing Record 558 | san jose
# Processing Record 559 | panzhihua
# Processing Record 560 | vostok
# Processing Record 561 | flinders
# Processing Record 562 | cabedelo
# Processing Record 563 | gumushane {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 564 | mogadishu
# Processing Record 565 | buraydah
# Processing Record 566 | ambilobe
# Processing Record 567 | himora {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 568 | santa rosa
# Processing Record 569 | pandan niog
# Processing Record 570 | smoky lake
# Processing Record 571 | jinchengjiang {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 572 | puerto el triunfo
# Processing Record 573 | cheyenne
# Processing Record 574 | kaeo
# Processing Record 575 | hanmer springs
# Processing Record 576 | omboue
# Processing Record 577 | aripuana
# Processing Record 578 | tubinskiy
# Processing Record 579 | natal
# Processing Record 580 | teguise
# Processing Record 581 | borama {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 582 | syracuse
# Processing Record 583 | oktyabrskoye
# Processing Record 584 | hamilton
# Processing Record 585 | khabary
# Processing Record 586 | erzin
# Processing Record 587 | cotonou
# Processing Record 588 | carutapera
# Processing Record 589 | dzhusaly {"cod":"404","message":"city not found"}
# No weather data
# Processing Record 590 | temba
# Processing Record 591 | puerto escondido
# Processing Record 592 | ilulissat
# Processing Record 593 | honiton
# Processing Record 594 | atasu
# Processing Record 595 | touros
# Processing Record 596 | saint-pierre
# Processing Record 597 | mitu
# Processing Record 598 | zarechnyy
# Processing Record 599 | nova prata
# Processing Record 600 | salinopolis
# Processing Record 601 | christchurch
# Processing Record 602 | beeville
# Processing Record 603 | ortakoy
# Processing Record 604 | namibe
# Processing Record 605 | tinsukia
# Processing Record 606 | san vicente
# Processing Record 607 | dossor
# Processing Record 608 | kendari
# Processing Record 609 | ayabaca
# Processing Record 610 | hoopstad
# Processing Record 611 | hambantota
# Processing Record 612 | uvinza
# Processing Record 613 | lishui
# Processing Record 614 | tamandare
# Processing Record 615 | umm lajj
# Processing Record 616 | kiruna
# Processing Record 617 | charlestown
# Processing Record 618 | niquelandia
# Processing Record 619 | gayeri
# Processing Record 620 | maykor
# Processing Record 621 | suamico

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_chosen.to_csv("WeatherData_12_15_2018.csv", index=False)
cities_chosen.dtypes
# Out:
# city_name      object
# Latitude       object
# Longitude      object
# Temperature    object
# Humidity       object
# Cloudiness     object
# Wind_Speed     object
# dtype: object

# %%
cities_chosen['Latitude'] = pd.to_numeric(cities_chosen['Latitude'],errors='coerce')
cities_chosen['Longitude'] = pd.to_numeric(cities_chosen['Longitude'],errors='coerce')
cities_chosen['Temperature'] = pd.to_numeric(cities_chosen['Temperature'], errors='coerce')
cities_chosen['Humidity'] = pd.to_numeric(cities_chosen['Humidity'], errors='coerce')
cities_chosen['Cloudiness'] = pd.to_numeric(cities_chosen['Cloudiness'], errors='coerce')
cities_chosen['Wind_Speed'] = pd.to_numeric(cities_chosen['Wind_Speed'], errors='coerce')

cities_chosen.dtypes
# Out:
# city_name       object
# Latitude       float64
# Longitude      float64
# Temperature    float64
# Humidity       float64
# Cloudiness     float64
# Wind_Speed     float64
# dtype: object

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(cities_chosen['Latitude'],cities_chosen['Temperature'], alpha = 0.5)

plt.title("Temperature (C) vs. Latitude <<Date of Analysis 12-15-2018>>")
plt.xlabel("Latitude")
plt.ylabel("Temperature (C)")
plt.savefig("Temperature_vs_Lat.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cities_chosen['Latitude'],cities_chosen['Humidity'], alpha = 0.5)

plt.title("Humidity vs. Latitude <<Date of Analysis 12-15-2018>>")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("Humidity_vs_Lat.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_chosen['Latitude'],cities_chosen['Cloudiness'], alpha = 0.5)

plt.title("Cloudiness vs. Latitude <<Date of Analysis 12-15-2018>>")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.savefig("Cloudiness_vs_Lat.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_chosen["Latitude"],cities_chosen["Wind_Speed"], alpha= 0.5)
plt.title("Wind Speed vs Latitude <<Date of Analysis 12-15-2018>>")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (km/h)")
plt.savefig("Wind Speed_vs_Lat.png")
plt.show()

# %% [markdown]
# ### Analysis
# * The data shows that weather is warmer as the equater is approached. However, as it is December, the southern hemisphere is summer so temperatures are above 0 degrees Celcius whereas northern hemisphere is winter so temperatures are colder.
# * There is no strong relationship between latitude and humidity. However, it is interesting to see that the equator has a weak relationship to humidity, no matter the latitude, there are cities with 100 humidity.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that cloudiness is very spread out globally.
# * There is no strong relationship between latitude and wind speed. However, it is interesting to see that many some cities have wind stronger than 17.5 km/h
